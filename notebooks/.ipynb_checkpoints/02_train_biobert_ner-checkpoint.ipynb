# %% [markdown]
# # 02 BioBERT NER Fine-Tuning
# This notebook runs fine-tuning of BioBERT on biomedical NER datasets (e.g., BC5CDR) using Hugging Face Trainer.

# %%
# checkgpu 
# !nvidia-smi

# %%
# Install dependencies
# !pip install transformers datasets seqeval

# %% [markdown]
# Clone repo from git hub

# %% [markdown]
# !git clone https://github.com/Yi104/biobert_biomarker_ner.git
# %cd biobert_biomarker_ner

# %%
# Google Drive setup:
from google.colab import drive
drive.mount('/content/drive')

# !cp -r outputs /content/drive/MyDrive/biobert_ner_outputs
